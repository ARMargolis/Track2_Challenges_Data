# %%
import numpy as np, pandas as pd

#get the submission file from GitHub
url='https://raw.githubusercontent.com/TRACK2-DATA-SCIENCE-2021/Track2_Challenges_Data/main/Challenge3/data/day3data.csv'
data=pd.read_csv(url, header=1)
sub_cols=['Bed','Ventilator','Remdesivir','Dexamethasone','Plasma','Casirivimab','Supplemental oxygen','Chloroquine','Total']
submission=pd.concat([data.iloc[:,:-1],pd.DataFrame(data=0, index=data.index, columns=sub_cols)], axis=1)
submission
# Out:
#     ID  Health  Rate of health decline  ...  Supplemental oxygen  Chloroquine  Total
# 0   48      87                     -25  ...                    0            0      0
# 1   49      34                     -25  ...                    0            0      0
# 2   50      45                      -1  ...                    0            0      0
# 3   51      33                      -3  ...                    0            0      0
# 4   52      89                      -5  ...                    0            0      0
# 5   53      87                      -7  ...                    0            0      0
# 6   54      98                     -10  ...                    0            0      0
# 7   55      78                     -14  ...                    0            0      0
# 8   56      98                     -25  ...                    0            0      0
# 9   57      79                     -27  ...                    0            0      0
# 10  58      89                     -28  ...                    0            0      0
# 11  59      95                     -33  ...                    0            0      0
# 12  60      64                     -37  ...                    0            0      0
# 13  61      43                     -40  ...                    0            0      0
# 14  62      57                     -45  ...                    0            0      0
# 15  63      37                     -50  ...                    0            0      0
# 16  64      97                     -52  ...                    0            0      0
# 17  65      57                     -55  ...                    0            0      0
# 18  66      48                     -60  ...                    0            0      0
# 19  67      90                     -65  ...                    0            0      0
# 20  68      99                     -67  ...                    0            0      0
# 21  69      99                     -77  ...                    0            0      0
# 22  70      99                     -79  ...                    0            0      0
# 23  71      79                     -80  ...                    0            0      0
# 24  72      88                     -80  ...                    0            0      0
# 25  73      47                     -84  ...                    0            0      0
# 26  74      79                     -85  ...                    0            0      0
# 27  75      89                     -86  ...                    0            0      0
# 28  76      54                     -88  ...                    0            0      0
# 29  77      24                     -90  ...                    0            0      0
# 30  78      86                     -90  ...                    0            0      0
# 31  79      48                     -95  ...                    0            0      0
# 32  80      44                     -95  ...                    0            0      0
# 33  81      55                     -98  ...                    0            0      0
# 34  82      57                     -99  ...                    0            0      0
# 35  83      58                     -99  ...                    0            0      0
# 36  84      60                     -99  ...                    0            0      0
# 37  85      57                     -99  ...                    0            0      0
# 38  86      29                     -99  ...                    0            0      0
#
# [39 rows x 12 columns]

# %%
import numpy as np

#Vector for quick addition of treatment
treatment_vec=np.array([0,1,1,5,30, 30,25,15,15,20,10])

#Sort sailors based on their predicted health at the end of day 2 with no treatment
end_health=submission['Health']+submission['Rate of health decline']
sickest_sailors=end_health.values.argsort(kind='mergesort')

#Put the thirty sickest (or all) sailors in beds
if submission.shape[0]<30:
  submission['Bed']=1
else:
  submission.loc[sickest_sailors[:30], 'Bed']=1

#Give the ten sickest (or all) sailors  ventilators 
if submission.shape[0]<10:
  submission['Ventilator']=1
else:
  submission.loc[sickest_sailors[:10], 'Ventilator']=1
  #Give the next ten sickest (or all) sailors sumplemental oxygen
  if submission.shape[0]<20:
    submission.loc[10:submission.shape[0], 'Supplemental oxygen']=1
  else:
    submission.loc[sickest_sailors[10:20], 'Supplemental oxygen']=1

#If health is greater than 90, the bonus points are worth more than health
submission.loc[lambda df:df['Health']+df['Rate of health decline']>90,
               ['Ventilator', 'Supplemental oxygen']]=0

#Recalculate total
perfect_fn=lambda x:100 if x>100 else x
submission['Total']=np.matmul(submission.values[:,:-1], treatment_vec)
submission['Total']=submission['Total'].apply(perfect_fn)
submission
# Out:
#     ID  Health  Rate of health decline  ...  Supplemental oxygen  Chloroquine  Total
# 0   48      87                     -25  ...                    0            0     62
# 1   49      34                     -25  ...                    0            0     14
# 2   50      45                      -1  ...                    0            0     49
# 3   51      33                      -3  ...                    0            0     35
# 4   52      89                      -5  ...                    0            0     84
# 5   53      87                      -7  ...                    0            0     80
# 6   54      98                     -10  ...                    0            0     88
# 7   55      78                     -14  ...                    0            0     64
# 8   56      98                     -25  ...                    0            0     73
# 9   57      79                     -27  ...                    0            0     52
# 10  58      89                     -28  ...                    0            0     61
# 11  59      95                     -33  ...                    0            0     62
# 12  60      64                     -37  ...                    0            0     32
# 13  61      43                     -40  ...                    1            0     28
# 14  62      57                     -45  ...                    0            0     17
# 15  63      37                     -50  ...                    1            0     12
# 16  64      97                     -52  ...                    0            0     50
# 17  65      57                     -55  ...                    1            0     27
# 18  66      48                     -60  ...                    1            0     13
# 19  67      90                     -65  ...                    0            0     30
# 20  68      99                     -67  ...                    0            0     37
# 21  69      99                     -77  ...                    0            0     27
# 22  70      99                     -79  ...                    0            0     25
# 23  71      79                     -80  ...                    1            0     24
# 24  72      88                     -80  ...                    1            0     33
# 25  73      47                     -84  ...                    0            0     -2
# 26  74      79                     -85  ...                    1            0     19
# 27  75      89                     -86  ...                    1            0     28
# 28  76      54                     -88  ...                    1            0     -9
# 29  77      24                     -90  ...                    0            0    -31
# 30  78      86                     -90  ...                    1            0     21
# 31  79      48                     -95  ...                    0            0    -12
# 32  80      44                     -95  ...                    0            0    -16
# 33  81      55                     -98  ...                    0            0     -8
# 34  82      57                     -99  ...                    0            0     -7
# 35  83      58                     -99  ...                    0            0     -6
# 36  84      60                     -99  ...                    0            0     -4
# 37  85      57                     -99  ...                    0            0     -7
# 38  86      29                     -99  ...                    0            0    -35
#
# [39 rows x 12 columns]

# %%
#Recalculate sickest sailors with beds, give the remaining medicine to the sickest soldiers, repeat
remaining_meds=[('Remdesivir',1), ('Dexamethasone', 18), ('Casirivimab',4), ('Plasma', 5), ('Chloroquine', 11)]
sailors_w_bed=submission.loc[lambda df:df.Bed==1].index

for med in remaining_meds:
  end_health=submission.loc[has_bed, 'Health']+submission.loc[has_bed,'Rate of health decline']
  sickest_sailors=end_health.values.argsort(kind='mergesort')
  submission.loc[sailors_w_bed[sickest_sailors[:med[1]]],med[0]]=1
  submission['Total']=np.matmul(submission.values[:,:-1], treatment_vec)
  submission['Total']=submission['Total'].apply(perfect_fn)

submission
# Out:
#     ID  Health  Rate of health decline  ...  Supplemental oxygen  Chloroquine  Total
# 0   48      87                     -25  ...                    0            0     62
# 1   49      34                     -25  ...                    0            0     14
# 2   50      45                      -1  ...                    0            0     49
# 3   51      33                      -3  ...                    0            0     35
# 4   52      89                      -5  ...                    0            0     84
# 5   53      87                      -7  ...                    0            0     80
# 6   54      98                     -10  ...                    0            0     88
# 7   55      78                     -14  ...                    0            0     64
# 8   56      98                     -25  ...                    0            0     73
# 9   57      79                     -27  ...                    0            0     52
# 10  58      89                     -28  ...                    0            0     61
# 11  59      95                     -33  ...                    0            0     62
# 12  60      64                     -37  ...                    0            0     32
# 13  61      43                     -40  ...                    1            0     53
# 14  62      57                     -45  ...                    0            0     17
# 15  63      37                     -50  ...                    1            0     37
# 16  64      97                     -52  ...                    0            0     50
# 17  65      57                     -55  ...                    1            0     52
# 18  66      48                     -60  ...                    1            0     38
# 19  67      90                     -65  ...                    0            0     30
# 20  68      99                     -67  ...                    0            0     37
# 21  69      99                     -77  ...                    0            0     27
# 22  70      99                     -79  ...                    0            0     25
# 23  71      79                     -80  ...                    1            0     49
# 24  72      88                     -80  ...                    1            0     33
# 25  73      47                     -84  ...                    0            1     33
# 26  74      79                     -85  ...                    1            0     44
# 27  75      89                     -86  ...                    1            0     28
# 28  76      54                     -88  ...                    1            1     26
# 29  77      24                     -90  ...                    0            1     34
# 30  78      86                     -90  ...                    1            0     46
# 31  79      48                     -95  ...                    0            1     53
# 32  80      44                     -95  ...                    0            1     49
# 33  81      55                     -98  ...                    0            1     42
# 34  82      57                     -99  ...                    0            1     28
# 35  83      58                     -99  ...                    0            1     29
# 36  84      60                     -99  ...                    0            1     31
# 37  85      57                     -99  ...                    0            1     28
# 38  86      29                     -99  ...                    0            1     60
#
# [39 rows x 12 columns]

# %%
submission.to_csv('Challenge3_Day3Submission.csv', index=False)

# %%
#Check to make sure we haven't run out of anything
#It looks like we're all good
submission.sum(axis=0)
# Out:
# ID                        2613
# Health                    2656
# Rate of health decline   -2296
# Bed                         30
# Ventilator                  10
# Remdesivir                   1
# Dexamethasone               18
# Plasma                       5
# Casirivimab                  4
# Supplemental oxygen         10
# Chloroquine                 11
# Total                     1735
# dtype: int64
